# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, concatenate, Conv2DTranspose
from tensorflow.keras.models import Model

# Define input image dimensions
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 3

# Define paths to training and testing data
train_data_dir = r'C:\Users\shail\Downloads\archive (1)\Training'
test_data_dir = r'C:\Users\shail\Downloads\archive (1)\Testing'

# Build the U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

# Contraction path
c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = Dropout(0.1)(c1)
c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = MaxPooling2D((2, 2))(c1)

c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = Dropout(0.1)(c2)
c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = MaxPooling2D((2, 2))(c2)

c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = Dropout(0.2)(c3)
c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = MaxPooling2D((2, 2))(c3)

c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = Dropout(0.2)(c4)
c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = MaxPooling2D(pool_size=(2, 2))(c4)

c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = Dropout(0.3)(c5)
c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

# Expansive path
u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = Dropout(0.2)(c6)
c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = Dropout(0.2)(c7)
c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = Dropout(0.1)(c8)
c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = Dropout(0.1)(c9)
c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

# Define the model
model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# Set up data generators with data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=16,
    class_mode='input',
    color_mode='rgb'
)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=16,
    class_mode='input',
    color_mode='rgb'
)

# Set up callbacks
callbacks = [
    EarlyStopping(patience=2, monitor='val_loss'),
    TensorBoard(log_dir='logs')
]

# Train the model
results = model.fit(
    train_generator,
    validation_data=test_generator,
    steps_per_epoch=train_generator.samples // 16,
    validation_steps=test_generator.samples // 16,
    epochs=1,
    callbacks=callbacks
)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  lambda_7 (Lambda)           (None, 128, 128, 3)          0         ['input_8[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 128, 128, 16)         448       ['lambda_7[0][0]']
#
#  dropout_24 (Dropout)        (None, 128, 128, 16)         0         ['conv2d_51[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 128, 128, 16)         2320      ['dropout_24[0][0]']
#
#  max_pooling2d_14 (MaxPooli  (None, 64, 64, 16)           0         ['conv2d_52[0][0]']
#  ng2D)
#
#  conv2d_53 (Conv2D)          (None, 64, 64, 32)           4640      ['max_pooling2d_14[0][0]']
#
#  dropout_25 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_53[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 64, 64, 32)           9248      ['dropout_25[0][0]']
#
#  max_pooling2d_15 (MaxPooli  (None, 32, 32, 32)           0         ['conv2d_54[0][0]']
#  ng2D)
#
#  conv2d_55 (Conv2D)          (None, 32, 32, 64)           18496     ['max_pooling2d_15[0][0]']
#
#  dropout_26 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_55[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 32, 32, 64)           36928     ['dropout_26[0][0]']
#
#  max_pooling2d_16 (MaxPooli  (None, 16, 16, 64)           0         ['conv2d_56[0][0]']
#  ng2D)
#
#  conv2d_57 (Conv2D)          (None, 16, 16, 128)          73856     ['max_pooling2d_16[0][0]']
#
#  dropout_27 (Dropout)        (None, 16, 16, 128)          0         ['conv2d_57[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 16, 16, 128)          147584    ['dropout_27[0][0]']
#
#  max_pooling2d_17 (MaxPooli  (None, 8, 8, 128)            0         ['conv2d_58[0][0]']
#  ng2D)
#
#  conv2d_59 (Conv2D)          (None, 8, 8, 256)            295168    ['max_pooling2d_17[0][0]']
#
#  dropout_28 (Dropout)        (None, 8, 8, 256)            0         ['conv2d_59[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 8, 8, 256)            590080    ['dropout_28[0][0]']
#
#  conv2d_transpose_10 (Conv2  (None, 16, 16, 128)          131200    ['conv2d_60[0][0]']
#  DTranspose)
#
#  concatenate_8 (Concatenate  (None, 16, 16, 256)          0         ['conv2d_transpose_10[0][0]',
#  )                                                                   'conv2d_58[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 16, 16, 128)          295040    ['concatenate_8[0][0]']
#
#  dropout_29 (Dropout)        (None, 16, 16, 128)          0         ['conv2d_61[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 16, 16, 128)          147584    ['dropout_29[0][0]']
#
#  conv2d_transpose_11 (Conv2  (None, 32, 32, 64)           32832     ['conv2d_62[0][0]']
#  DTranspose)
#
#  concatenate_9 (Concatenate  (None, 32, 32, 128)          0         ['conv2d_transpose_11[0][0]',
#  )                                                                   'conv2d_56[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 32, 32, 64)           73792     ['concatenate_9[0][0]']
#
#  dropout_30 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_63[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 32, 32, 64)           36928     ['dropout_30[0][0]']
#
#  conv2d_transpose_12 (Conv2  (None, 64, 64, 32)           8224      ['conv2d_64[0][0]']
#  DTranspose)
#
#  concatenate_10 (Concatenat  (None, 64, 64, 64)           0         ['conv2d_transpose_12[0][0]',
#  e)                                                                  'conv2d_54[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 64, 64, 32)           18464     ['concatenate_10[0][0]']
#
#  dropout_31 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_65[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 64, 64, 32)           9248      ['dropout_31[0][0]']
#
#  conv2d_transpose_13 (Conv2  (None, 128, 128, 16)         2064      ['conv2d_66[0][0]']
#  DTranspose)
#
#  concatenate_11 (Concatenat  (None, 128, 128, 32)         0         ['conv2d_transpose_13[0][0]',
#  e)                                                                  'conv2d_52[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 128, 128, 16)         4624      ['concatenate_11[0][0]']
#
#  dropout_32 (Dropout)        (None, 128, 128, 16)         0         ['conv2d_67[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 128, 128, 16)         2320      ['dropout_32[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 128, 128, 1)          17        ['conv2d_68[0][0]']
#
# ==================================================================================================
# Total params: 1941105 (7.40 MB)
# Trainable params: 1941105 (7.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.
# 357/357 [==============================] - 786s 2s/step - loss: 0.3920 - accuracy: 0.1447 - val_loss: 0.3522 - val_accuracy: 0.1630
